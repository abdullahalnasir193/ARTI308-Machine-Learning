# %% [markdown]
# <a href="https://colab.research.google.com/github/abdullahalnasir193/ARTI308-Machine-Learning/blob/main/Lab2_Predicting_Car_Prices.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
dataset=pd.read_csv("global_cars_enhanced.csv")
print(dataset.shape)

# %%
dataset.head()

# %%
dataset.info()
